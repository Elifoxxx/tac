# %% [markdown]
# # Extraction de Keywords

# %% [markdown]
# ## Imports

# %%
import os
import yake

# %% [markdown]
# ## Extraire les mots clés d'un document avec Yake

# %% [markdown]
# https://github.com/LIAAD/yake

# %%
# Instantier l'extracteur de mots clés
kw_extractor = yake.KeywordExtractor(lan="fr", top=50)
kw_extractor

# %%
# Lister les Fichiers
data_path = "../data/txt/camille_lesoir_sample/txt"
files = [f for f in os.listdir(data_path) if f.endswith('.txt')]

# %%
# Imprimer le nombre de fichiers identifiés
len(files)
# Out:
# 7936

# %%
# Les fichiers de 1934
files = [f for f in files if '1934' in f]

# %%
# Les dix premiers fichiers
files[:10]
# Out:
# ['KB_JB838_1934-01-04_01-00011.txt',
#  'KB_JB838_1934-01-05_01-00013.txt',
#  'KB_JB838_1934-01-09_01-00010.txt',
#  'KB_JB838_1934-01-14_01-00011.txt',
#  'KB_JB838_1934-01-16_01-00004.txt',
#  'KB_JB838_1934-01-17_01-00003.txt',
#  'KB_JB838_1934-01-17_01-00014.txt',
#  'KB_JB838_1934-01-18_01-00005.txt',
#  'KB_JB838_1934-01-21_01-00010.txt',
#  'KB_JB838_1934-01-24_01-00005.txt']

# %%
# Choisir un fichier
this_file = files[0]
this_file
# Out:
# 'KB_JB838_1934-01-04_01-00011.txt'

# %%
# Récupérer le texte du fichier
text = open(os.path.join(data_path, this_file), 'r', encoding='utf-8').read()
text[:500]
# Out:
# "4 JANVIER 1934 LE SO!$ 11. Le bâtonnet de 5 Cubes LIEB1G (avec Bon pour Chromos) ?r. 2.50 Les Cubes de Bouillon LIEBIG Un Cube de Bouillon Liebig contient 2 tablettes. Chaque tablette permet de préparer 1/2 litre d’excellent bouillon à base d'Extrait de Viande Liebig et de la saveur de légumes frais. La présentation en tablettes du Cube Liebig, nouvelle et si pratique, rend ce bouillon concentré très facile à doser et à dissoudre. LE CUBE LIEBIG DANS TOUTE CUISINE SITUATION STABLE est offerte.à "

# %%
# Extraire les mots clés de ce texte
keywords = kw_extractor.extract_keywords(text)
keywords
# Out:
# [('dem', np.float64(0.0012853483779238892)),
#  ('Rossel', np.float64(0.0035596805095076587)),
#  ('rue', np.float64(0.003988589596839352)),
#  ('Agence Rossel', np.float64(0.00512882726300402)),
#  ('dem.', np.float64(0.005390949843036508)),
#  ('Ecrire Agence Rossel', np.float64(0.006881048754283212)),
#  ('Ecr', np.float64(0.009238400751343601)),
#  ('serveuse', np.float64(0.009839783607754678)),
#  ('DEMANDE', np.float64(0.009883380805646089)),
#  ('Bon', np.float64(0.010545105245928128)),
#  ('Ecrire', np.float64(0.012676550981669778)),
#  ('place', np.float64(0.014930582253871895)),
#  ('FEMME dem', np.float64(0.015234717605950911)),
#  ('prés', np.float64(0.018129379127548837)),
#  ('DEM. serveuse', np.float64(0.01972060674112825)),
#  ('faire', np.float64(0.020021304516457998)),
#  ('servante', np.float64(0.020124149280024838)),
#  ('Maison FEMME dem', np.float64(0.020309492498638546)),
#  ('fille', np.float64(0.023911051785751817)),
#  ('cherche', np.float64(0.024093065617577885)),
#  ('FEMME', np.float64(0.024219148429118577)),
#  ('ans', np.float64(0.025143272812531595)),
#  ('MAISON', np.float64(0.025443862392908082)),
#  ('Cube Liebig', np.float64(0.025484608422389705)),
#  ('CHARCUTERIE dem', np.float64(0.02619988282546398)),
#  ('Jours', np.float64(0.02627847891146861)),
#  ('dem. place', np.float64(0.027159009616203347)),
#  ('BONS', np.float64(0.027417273639413133)),
#  ('demande place', np.float64(0.02955969702985591)),
#  ('Agence', np.float64(0.02976691162547641)),
#  ('DEMANDE servante', np.float64(0.02991034821220737)),
#  ('MONSIEUR', np.float64(0.03049149254193983)),
#  ('FEM. dem.', np.float64(0.030878078037691666)),
#  ('vente', np.float64(0.0312901540198612)),
#  ('courant', np.float64(0.031519217179270684)),
#  ('demande serveuse', np.float64(0.032137063083538205)),
#  ('FEM', np.float64(0.03307367756927308)),
#  ('jne', np.float64(0.03518725335720571)),
#  ('rue Van', np.float64(0.03612477532092446)),
#  ('Bouillon LIEBIG', np.float64(0.03621417216175365)),
#  ('JNE fem. dem.', np.float64(0.03930364689794376)),
#  ('Ag.Rossel', np.float64(0.03990941649446197)),
#  ('DEM. fem', np.float64(0.04141269630063563)),
#  ('Ecrire Agence', np.float64(0.042551065641686765)),
#  ('cherche place', np.float64(0.04300326503978034)),
#  ('Valton', np.float64(0.0441909983750041)),
#  ('réf', np.float64(0.044789581290129006)),
#  ('MANUCURE dem', np.float64(0.045493639112023615)),
#  ('trav', np.float64(0.04571808832782764)),
#  ('jeune', np.float64(0.04597155370961314))]

# %%
# Ne garder que les bigrammes
kept = []
for kw, score in keywords:
    words = kw.split()
    if len(words) == 2:
        kept.append(kw)
kept
# Out:
# ['Agence Rossel',
#  'FEMME dem',
#  'DEM. serveuse',
#  'Cube Liebig',
#  'CHARCUTERIE dem',
#  'dem. place',
#  'demande place',
#  'DEMANDE servante',
#  'FEM. dem.',
#  'demande serveuse',
#  'rue Van',
#  'Bouillon LIEBIG',
#  'DEM. fem',
#  'Ecrire Agence',
#  'cherche place',
#  'MANUCURE dem']

# %% [markdown]
# ## Faire la même opération sur tous les documents

# %%
for f in sorted(files)[:10]:
    text = open(os.path.join(data_path, f), 'r', encoding="utf-8").read()
    keywords = kw_extractor.extract_keywords(text)
    kept = []
    for kw, score in keywords:
        words = kw.split()
        if len(words) == 2:
            kept.append(kw)
    print(f"{f} mentions these keywords: {', '.join(kept)}...")
# Out:
# KB_JB838_1934-01-04_01-00011.txt mentions these keywords: Agence Rossel, FEMME dem, DEM. serveuse, Cube Liebig, CHARCUTERIE dem, dem. place, demande place, DEMANDE servante, FEM. dem., demande serveuse, rue Van, Bouillon LIEBIG, DEM. fem, Ecrire Agence, cherche place, MANUCURE dem...
# KB_JB838_1934-01-05_01-00013.txt mentions these keywords: AGENCE ROSSEL, Ecrire AGENCE, noyer poli, FINE LINGERIE, bas prix, MANUCURE rue, noyer poil, Prix modérés, rue Scailquin...
# KB_JB838_1934-01-09_01-00010.txt mentions these keywords: bel app, REMEDES RHUMES, Agence ROSSEL, app. mod, VIEUX REMEDES, rue Van, Pte Louise, confort moderne...
# KB_JB838_1934-01-14_01-00011.txt mentions these keywords: BELLE MAISON, Ledit notaire, BONNE MAISON, vendra publiquement, notaire vendra, BATIR rue, notaire Camille, MAISON D’HABITATION, notaire Georges, VENTE PUBLIQUE, notaires CLAES...
# KB_JB838_1934-01-16_01-00004.txt mentions these keywords: Mme STAVISKY, Janvier Mars, Novembre Janvier, Mars Mai, Mai Juillet, Joseph Langlois, Juillet Octobre, Stavisky n’a, ENFANTS ADMIS, Mme Joseph, Paris Paris, Janvier Préc...
# KB_JB838_1934-01-17_01-00003.txt mentions these keywords: GOUVERNEMENT ALLEMAND, Pierre Cot, COMMUNAUTÉ ASSYRIENNE, SARRE Paris, gouvernement bulgare, Front allemand, ASSYRIENNE Genève, gouverneur général, Comité financier...
# KB_JB838_1934-01-17_01-00014.txt mentions these keywords: Agence Rossel, Ecrire Agence, Cause santé, PRETS HYPOTHECAIRES, cause double, Emile Jacqmain, rue Léopold...
# KB_JB838_1934-01-18_01-00005.txt mentions these keywords: demeurant rue, REFORMES FISCALES, STAVISKY Paris, D’UN ACCIDENT, l’affaire Stavisky, cours d’une, Ligue belge, d’une auto...
# KB_JB838_1934-01-21_01-00010.txt mentions these keywords: BELLE MAISON, Ledit notaire, BONNE MAISON, notaire VAN, MAISON RENTIER, notaire CLAES, notaire Léon, vendra publiquement, BATIR rue, notaire vendra, MAISON D’HABITATION...
# KB_JB838_1934-01-24_01-00005.txt mentions these keywords: Cour d’assises, demeurant rue, Mission Commerciale, lundi soir, Cour suprême, Mission fut, Mission belge, Commerciale Belge, Tribunal correctionnel...
