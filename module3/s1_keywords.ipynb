# %% [markdown]
# # Extraction de Keywords

# %% [markdown]
# ## Imports

# %%
import os
import yake

# %% [markdown]
# ## Extraire les mots clés d'un document avec Yake

# %% [markdown]
# https://github.com/LIAAD/yake

# %%
# Instantier l'extracteur de mots clés
kw_extractor = yake.KeywordExtractor(lan="fr", top=50)
kw_extractor

# %%
# Lister les Fichiers
data_path = "../data/txt"
files = [f for f in os.listdir(data_path) if f.endswith('.txt')]

# %%
# Imprimer le nombre de fichiers identifiés
len(files)
# Out:
# 7986

# %%
# Les fichiers de 1934
files = [f for f in files if '194' in f]

# %%
# Les dix premiers fichiers
files[:10]
# Out:
# ['KB_JB427_1949-07-18_01-00008.txt',
#  'KB_JB449_1947-08-29_01-00003.txt',
#  'KB_JB555_1940-03-01_01-00004.txt',
#  'KB_JB638_1946-07-18_01-00003.txt',
#  'KB_JB835_1949-09-18_01-00004.txt',
#  'KB_JB838_1940-01-04_01-00001.txt',
#  'KB_JB838_1940-01-05_01-00009.txt',
#  'KB_JB838_1940-01-07_01-00014.txt',
#  'KB_JB838_1940-01-10_01-00003.txt',
#  'KB_JB838_1940-01-11_01-00004.txt']

# %%
# Choisir un fichier
this_file = files[0]
this_file
# Out:
# 'KB_JB427_1949-07-18_01-00008.txt'

# %%
# Récupérer le texte du fichier
text = open(os.path.join(data_path, this_file), 'r', encoding='utf-8').read()
text[:500]
# Out:
# "Lundi 18 Juillet 1949 WSSSr \nHBjUa^giLA LIBRE BELGIQUE BS^B \nID H • B B B • • • B D • =J I 11 tt l> U B H M E H • B B 9 B B B B B BIli CHRONIQUE FEMININE \nMéditation sur la beauté \n•••-\nc Tu me diras lequel tu préfè\xad\nres, c'est-à-dire celui que tu vou\xad\ndrais avoir devant les yeux pour le \nreste de ta vie sans en être fati\xad\nguée jamais, et nous le volerons \nensemble ! », me dit mon oncle. \nSur cette résolution pleine d'hon\xad\nnêteté, nous nous séparâmes, trou\xad\nvant que ta contemplation parfai\xad\nte d"

# %%
# Extraire les mots clés de ce texte
keywords = kw_extractor.extract_keywords(text)
keywords
# Out:
# [('BIli CHRONIQUE FEMININE', np.float64(0.0011186237398072539)),
#  ('CHRONIQUE FEMININE Méditation', np.float64(0.002071352807374001)),
#  ('vous', np.float64(0.0032339375728419016)),
#  ('CHRONIQUE FEMININE', np.float64(0.0046004641036852326)),
#  ('Vous avez', np.float64(0.010039503326041721)),
#  ('beauté', np.float64(0.010814406148108054)),
#  ('giLA LIBRE BELGIQUE', np.float64(0.010829543302302503)),
#  ("c'est", np.float64(0.01088608598045566)),
#  ('vous vous', np.float64(0.012345499455479917)),
#  ('vous vous sen', np.float64(0.013010233726050592)),
#  ('beau', np.float64(0.015289131415848825)),
#  ('BIli CHRONIQUE', np.float64(0.016221487391293136)),
#  ('jeune', np.float64(0.016400068526375124)),
#  ('vie', np.float64(0.023676167020677933)),
#  ("J'ai", np.float64(0.025512994146682753)),
#  ('jeune homme', np.float64(0.0257094971573222)),
#  ('jeune fille', np.float64(0.026785492814509565)),
#  ('ans', np.float64(0.027337470102563752)),
#  ('Dieu', np.float64(0.028679256381304336)),
#  ("C'est beau", np.float64(0.02961806207288834)),
#  ('FEMININE Méditation', np.float64(0.029679224436487153)),
#  ("N'est", np.float64(0.03165794125173674)),
#  ("qu'il", np.float64(0.035375855986460016)),
#  ('LIBRE BELGIQUE', np.float64(0.03993746076704624)),
#  ('jeunes filles', np.float64(0.04017823922176435)),
#  ('yeux', np.float64(0.04099219679011493)),
#  ('jeunes', np.float64(0.04100017131593781)),
#  ('vous remercie', np.float64(0.041563027928638314)),
#  ('filles', np.float64(0.04319354544057939)),
#  ('fille', np.float64(0.04319354544057939)),
#  ("d'un", np.float64(0.04575301496934259)),
#  ('ment', np.float64(0.048281120737716385)),
#  ('jamais', np.float64(0.04966377582258138)),
#  ("d'une jeune fille", np.float64(0.050275313432076724)),
#  ('temps', np.float64(0.051878968252291116)),
#  ('avez', np.float64(0.05287512562931881)),
#  ('puis', np.float64(0.053742255983926845)),
#  ('serait', np.float64(0.05439061718284683)),
#  ("c'est Dieu", np.float64(0.055353741656424434)),
#  ('faire', np.float64(0.05546284682135977)),
#  ('jeune fille fort', np.float64(0.05670191005585102)),
#  ('WSSSr HBjUa', np.float64(0.058071904073947085)),
#  ('petites', np.float64(0.05838727419233337)),
#  ('volerons ensemble', np.float64(0.058494097723014345)),
#  ('voir', np.float64(0.0600561433377678)),
#  ('homme', np.float64(0.0661467921471455)),
#  ('Juillet', np.float64(0.0669752311037416)),
#  ('BELGIQUE', np.float64(0.06767124022289764)),
#  ('CHRONIQUE', np.float64(0.06767124022289764)),
#  ('FEMININE', np.float64(0.06767124022289764))]

# %%
# Ne garder que les bigrammes
kept = []
for kw, score in keywords:
    words = kw.split()
    if len(words) == 2:
        kept.append(kw)
kept
# Out:
# ['CHRONIQUE FEMININE',
#  'Vous avez',
#  'vous vous',
#  'BIli CHRONIQUE',
#  'jeune homme',
#  'jeune fille',
#  "C'est beau",
#  'FEMININE Méditation',
#  'LIBRE BELGIQUE',
#  'jeunes filles',
#  'vous remercie',
#  "c'est Dieu",
#  'WSSSr HBjUa',
#  'volerons ensemble']

# %% [markdown]
# ## Faire la même opération sur tous les documents

# %%
for f in sorted(files)[:10]:
    text = open(os.path.join(data_path, f), 'r', encoding="utf-8").read()
    keywords = kw_extractor.extract_keywords(text)
    kept = []
    for kw, score in keywords:
        words = kw.split()
        if len(words) == 2:
            kept.append(kw)
    print(f"{f} mentions these keywords: {', '.join(kept)}...")
# Out:
# KB_JB427_1949-07-18_01-00008.txt mentions these keywords: CHRONIQUE FEMININE, Vous avez, vous vous, BIli CHRONIQUE, jeune homme, jeune fille, C'est beau, FEMININE Méditation, LIBRE BELGIQUE, jeunes filles, vous remercie, c'est Dieu, WSSSr HBjUa, volerons ensemble...
# KB_JB449_1947-08-29_01-00003.txt mentions these keywords: Mgr Lecouvet, Dimanche prochain, ALLOCATIONS COMPENSATOIRES, Ecole Industrielle, nouveau doyen, ler septembre, l'abbé Lebrun, Fanfare Royale, Lundi ler...
# KB_JB555_1940-03-01_01-00004.txt mentions these keywords: Défense Nationale, présente loi, jeudi matin, L'INDEPENDANCE BELGE, Ligue Nationale, d'une amende, trains sanitaires, Société Nationale, Commission bancaire, ment d'un, présence d'un, général Michiels, Jeudi soir, D'autre part, Paul CLAUDEL...
# KB_JB638_1946-07-18_01-00003.txt mentions these keywords: MEUSE Audi, Nord Belg, Nord Gilly, Helcht-ren Idem, Idem Sde, Camplne Idem, Gaz Liège, vie sauve...
# KB_JB835_1949-09-18_01-00004.txt mentions these keywords: Van Hee, van ZEELAND, van Van, Van Alphen, Hee dans, Van Ceulebroeck, délégation belge, Van Hoy, Boosere Paula, tuer Paula...
# KB_JB838_1940-01-04_01-00001.txt mentions these keywords: nous avons, nous dit-on, qu’il nous, nous qu’il, nous faut, milieux politiques, foi nous, C’est qu’il, ROYALE BRUXELLES...
# KB_JB838_1940-01-05_01-00009.txt mentions these keywords: Agence Rossel, JNE FILLE, l’Agence Rossel, TAVERNE Dem, bon. référ, DEM. bon, rue Washington, dem. place...
# KB_JB838_1940-01-07_01-00014.txt mentions these keywords: POINTS NOIRS, Reproduction Interdite, rue Van, Camionnette Chevrolet, Création Paquln, POCHE EXTERIEURE, MILTON AUTOS, BRUXELLES Rue...
# KB_JB838_1940-01-10_01-00003.txt mentions these keywords: gouvernement finlandais, presse soviétique, division soviétique, janvier Havas, DERNIERES NOUVELLES, navires britanniques, troupes russes, guerre italien, troupes finlandaises...
# KB_JB838_1940-01-11_01-00004.txt mentions these keywords: forces aériennes, United Press, Conseil général, France Londres, comte Csaky, comte Ciano, Tribunal correctionnel, Air Force, Conseil communal, Mardi soir...
